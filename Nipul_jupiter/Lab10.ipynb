# %%
import numpy as np
import pandas as pd

# %%
ls_org = pd.read_csv('ls-01.csv')

# %%
ls_1 = ls_org.copy()
ls_2 = ls_1.copy()

# %%
ls_1.head()
# Out:
#    Age  Gender      Region   Income Married Children  Car Mortgage  Pep
# 0   48     NaN  INNER_CITY  17546.0      NO      YES   NO       NO  YES
# 1   40    MALE        TOWN  30085.1     YES      YES  YES      YES   NO
# 2   51  FEMALE  INNER_CITY  16575.4     YES       NO  YES       NO   NO
# 3   23  FEMALE        TOWN  20375.4     YES      YES   NO       NO   NO
# 4   57  FEMALE       RURAL  50576.3     YES       NO   NO       NO   NO

# %%
ls_1.isnull().sum()
# Out:
# Age          0
# Gender      49
# Region       0
# Income       0
# Married      0
# Children     0
# Car          0
# Mortgage     0
# Pep          0
# dtype: int64

# %%
pd.isna(ls_1['Gender'])
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# Name: Gender, Length: 286, dtype: bool

# %%
ls_1.dropna(axis=1,thresh=286,inplace=True)

# %%
ls_1.head()
# Out:
#    Age      Region   Income Married Children  Car Mortgage  Pep
# 0   48  INNER_CITY  17546.0      NO      YES   NO       NO  YES
# 1   40        TOWN  30085.1     YES      YES  YES      YES   NO
# 2   51  INNER_CITY  16575.4     YES       NO  YES       NO   NO
# 3   23        TOWN  20375.4     YES      YES   NO       NO   NO
# 4   57       RURAL  50576.3     YES       NO   NO       NO   NO

# %%
ls_1=ls_org.copy()
ls_2 = ls_1.copy()

# %%
ls_1.head()
# Out:
#    Age  Gender      Region   Income Married Children  Car Mortgage  Pep
# 0   48     NaN  INNER_CITY  17546.0      NO      YES   NO       NO  YES
# 1   40    MALE        TOWN  30085.1     YES      YES  YES      YES   NO
# 2   51  FEMALE  INNER_CITY  16575.4     YES       NO  YES       NO   NO
# 3   23  FEMALE        TOWN  20375.4     YES      YES   NO       NO   NO
# 4   57  FEMALE       RURAL  50576.3     YES       NO   NO       NO   NO

# %%
ls_1.fillna({'Gender': 0}, inplace=True)

# %%
ls_1.head()
# Out:
#    Age  Gender      Region   Income Married Children  Car Mortgage  Pep
# 0   48       0  INNER_CITY  17546.0      NO      YES   NO       NO  YES
# 1   40    MALE        TOWN  30085.1     YES      YES  YES      YES   NO
# 2   51  FEMALE  INNER_CITY  16575.4     YES       NO  YES       NO   NO
# 3   23  FEMALE        TOWN  20375.4     YES      YES   NO       NO   NO
# 4   57  FEMALE       RURAL  50576.3     YES       NO   NO       NO   NO

# %%
ls_1.groupby(['Gender'])['Gender'].count()
# Out:
# Gender
# 0          49
# FEMALE    122
# MALE      115
# Name: Gender, dtype: int64

# %%
ls_1.fillna({'Gender': 'missing'})
# Out:
#      Age  Gender      Region   Income Married Children  Car Mortgage  Pep
# 0     48       0  INNER_CITY  17546.0      NO      YES   NO       NO  YES
# 1     40    MALE        TOWN  30085.1     YES      YES  YES      YES   NO
# 2     51  FEMALE  INNER_CITY  16575.4     YES       NO  YES       NO   NO
# 3     23  FEMALE        TOWN  20375.4     YES      YES   NO       NO   NO
# 4     57  FEMALE       RURAL  50576.3     YES       NO   NO       NO   NO
# ..   ...     ...         ...      ...     ...      ...  ...      ...  ...
# 281   47    MALE  INNER_CITY  44658.6      NO      YES  YES       NO  YES
# 282   44    MALE       RURAL  32762.5      NO       NO   NO      YES   NO
# 283   23    MALE       RURAL  16403.8     YES       NO  YES       NO   NO
# 284   28  FEMALE  INNER_CITY  21184.7     YES      YES  YES       NO  YES
# 285   64  FEMALE  INNER_CITY  49917.3     YES       NO  YES      YES   NO
#
# [286 rows x 9 columns]

# %%
ls_1.head()
# Out:
#    Age  Gender      Region   Income Married Children  Car Mortgage  Pep
# 0   48       0  INNER_CITY  17546.0      NO      YES   NO       NO  YES
# 1   40    MALE        TOWN  30085.1     YES      YES  YES      YES   NO
# 2   51  FEMALE  INNER_CITY  16575.4     YES       NO  YES       NO   NO
# 3   23  FEMALE        TOWN  20375.4     YES      YES   NO       NO   NO
# 4   57  FEMALE       RURAL  50576.3     YES       NO   NO       NO   NO

# %%
#Import the data set as
Dataset=[['milk','onion','nugmeg','kidney beans','eggs','yogurt'],
      ['oill','onion','nutmeg', 'kidney beans','eggs','yogurt'],
      ['milk','apple', 'kidney beans','eggs'],
      ['milk','unicorn','corn','kidney beans', 'yogurt'] ,
      ['corn','onion','onion' , 'kidney beans','ice cream','eggs']]

# %%
# !pip install mlxtend

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
#creating the dataset as a dataframe
T = TransactionEncoder()
T_arr = T.fit(Dataset).transform(Dataset)

# %%
df = pd.DataFrame(T_arr,columns=T.columns_)

# %%
df
# Out:
#    apple   corn   eggs  ice cream  kidney beans   milk  nugmeg  nutmeg   oill  \
# 0  False  False   True      False          True   True    True   False  False
# 1  False  False   True      False          True  False   False    True   True
# 2   True  False   True      False          True   True   False   False  False
# 3  False   True  False      False          True   True   False   False  False
# 4  False   True   True       True          True  False   False   False  False
#
#    onion  unicorn  yogurt
# 0   True    False    True
# 1   True    False    True
# 2  False    False   False
# 3  False     True    True
# 4   True    False   False

# %%
# Create the possible item set for the min_support=0.6 using apriori algorithum
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df,min_support=0.6,use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.8                       (eggs)
# 1       1.0               (kidney beans)
# 2       0.6                       (milk)
# 3       0.6                      (onion)
# 4       0.6                     (yogurt)
# 5       0.8         (eggs, kidney beans)
# 6       0.6                (eggs, onion)
# 7       0.6         (milk, kidney beans)
# 8       0.6        (onion, kidney beans)
# 9       0.6       (yogurt, kidney beans)
# 10      0.6  (eggs, onion, kidney beans)

# %%
# Create the association rule mining
from mlxtend.frequent_patterns import association_rules

result=association_rules(frequent_itemsets,metric='confidence',min_threshold=0.7)

# %%
result
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (eggs)         (kidney beans)                 0.8
# 1          (kidney beans)                 (eggs)                 1.0
# 2                  (eggs)                (onion)                 0.8
# 3                 (onion)                 (eggs)                 0.6
# 4                  (milk)         (kidney beans)                 0.6
# 5                 (onion)         (kidney beans)                 0.6
# 6                (yogurt)         (kidney beans)                 0.6
# 7           (eggs, onion)         (kidney beans)                 0.6
# 8    (eggs, kidney beans)                (onion)                 0.8
# 9   (onion, kidney beans)                 (eggs)                 0.6
# 10                 (eggs)  (onion, kidney beans)                 0.8
# 11                (onion)   (eggs, kidney beans)                 0.6
#
# ...

# %%
# Create the sub set of antecedents,consequents,support,confidence,lift
result1= result[['antecedents','consequents','support','confidence','lift']]

# %%
result1
# Out:
#               antecedents            consequents  support  confidence  lift
# 0                  (eggs)         (kidney beans)      0.8        1.00  1.00
# 1          (kidney beans)                 (eggs)      0.8        0.80  1.00
# 2                  (eggs)                (onion)      0.6        0.75  1.25
# 3                 (onion)                 (eggs)      0.6        1.00  1.25
# 4                  (milk)         (kidney beans)      0.6        1.00  1.00
# 5                 (onion)         (kidney beans)      0.6        1.00  1.00
# 6                (yogurt)         (kidney beans)      0.6        1.00  1.00
# 7           (eggs, onion)         (kidney beans)      0.6        1.00  1.00
# 8    (eggs, kidney beans)                (onion)      0.6        0.75  1.25
# 9   (onion, kidney beans)                 (eggs)      0.6        1.00  1.25
# 10                 (eggs)  (onion, kidney beans)      0.6        0.75  1.25
# ...

# %%
#Retrieve the itemset which itemset have confidence >= 1
item = result1[result1['confidence']>= 1]
item
# Out:
#               antecedents           consequents  support  confidence  lift
# 0                  (eggs)        (kidney beans)      0.8         1.0  1.00
# 3                 (onion)                (eggs)      0.6         1.0  1.25
# 4                  (milk)        (kidney beans)      0.6         1.0  1.00
# 5                 (onion)        (kidney beans)      0.6         1.0  1.00
# 6                (yogurt)        (kidney beans)      0.6         1.0  1.00
# 7           (eggs, onion)        (kidney beans)      0.6         1.0  1.00
# 9   (onion, kidney beans)                (eggs)      0.6         1.0  1.25
# 11                (onion)  (eggs, kidney beans)      0.6         1.0  1.25
